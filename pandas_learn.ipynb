# %%
import pandas as pd

# %%
Sdf = pd.read_csv('p_learn/pokemon_data.csv')
df_xlsx = pd.read_excel('p_learn/pokemon_data_x.xlsx') # reading non csv files
# df_xlsx = pd.read_csv('p_learn/pokemon_data.txt',delimiter='\t') 
df.head() #tail
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ## Reading datasets

# %%
# Read all headers
df.columns

# Read Specific columns
df[['Name','HP']].head()

# Read each rows
df.iloc[0:4]

# (or) 
for index,row in df.iterrows():
    if row['Name'] == "Venusaur":
        print("Solution: ",index,row['HP'])

# (or) for more specific
df.loc[(df["Type 1"] == "Fire") & (df['Attack'] > 100)] # returns only filtered rows

# Read Specific rows (R,C)
# df.iloc[2,2]
# Out:
# Solution:  2 80
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 147  136                    Flareon   Fire       NaN   65     130       60
# 263  244                      Entei   Fire       NaN  115     115       85
# 270  250                      Ho-oh   Fire    Flying  106     130       90
# 278  257                   Blaziken   Fire  Fighting   80     120       70
# 279  257      BlazikenMega Blaziken   Fire  Fighting   80     160       80
# 354  323      CameruptMega Camerupt   Fire    Ground   70     120      100
# 437  392                  Infernape   Fire  Fighting   76     104       71
# 559  500                     Emboar   Fire  Fighting  110     123       65
# ...

# %% [markdown]
# ## Sorting / Describing

# %%
df.describe() # mean  , count, min, max etc..

df.sort_values(['Type 1','Speed'], ascending = [1,1]) # ascending = False - leads to decending order
# Out:
#        #                  Name Type 1    Type 2  HP  Attack  Defense  Sp. Atk  \
# 230  213               Shuckle    Bug      Rock  20      10      230       10
# 219  204                Pineco    Bug       NaN  50      65       90       35
# 289  266               Silcoon    Bug       NaN  50      35       55       25
# 291  268               Cascoon    Bug       NaN  50      35       55       25
# 288  265               Wurmple    Bug       NaN  45      45       35       20
# ..   ...                   ...    ...       ...  ..     ...      ...      ...
# 713  647  KeldeoOrdinary Forme  Water  Fighting  91      72       90      129
# 714  647  KeldeoResolute Forme  Water  Fighting  91      72       90      129
# 130  121               Starmie  Water   Psychic  60      75       85      100
# 466  419              Floatzel  Water       NaN  85     105       55       85
# 726  658              Greninja  Water      Dark  72      95       67      103
#
# ...

# %% [markdown]
# ## Making Changes in Data

# %%
# Dropping
df = df.drop(columns=['Generation'])
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Legendary
# 0       65     45      False
# 1       80     60      False
# 2      100     80      False
# 3      120     80      False
# 4       50     65      False

# %%
#df['Total'] =  df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Def'] + df['Sp. Atk'] + df['Speed'] 
df.head()

# optimized
df['Total'] = df.iloc[: , 4:10].sum(axis=1) # : - means all (R , C) || axis = 0 means horizontal
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Legendary  Total
# 0       65     45      False    318
# 1       80     60      False    405
# 2      100     80      False    525
# 3      120     80      False    625
# 4       50     65      False    309

# %%
# Rearranging
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + cols[4:11]]
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Legendary
# 0       65       65     45      False
# 1       80       80     60      False
# 2      100      100     80      False
# 3      122      120     80      False
# 4       60       50     65      False

# %% [markdown]
# ## Saving the Data

# %%
#df.to_excel('',index=False)

# %% [markdown]
# ## Filtering Data

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Total'] > 500) ]  
new_df = new_df.reset_index(drop=True) # Reset index for new df || drop=True - to remove index column name
new_df.to_csv('filtered.csv')
# new_df.reset_index(drop=True, inplace=True) - inplace=True: Modifies the original object directly.
new_df
# Out:
#       #                     Name Type 1    Type 2  Total   HP  Attack  \
# 0     3                 Venusaur  Grass    Poison    525   80      82
# 1     3    VenusaurMega Venusaur  Grass    Poison    625   80     100
# 2   103                Exeggutor  Grass   Psychic    520   95      95
# 3   154                 Meganium  Grass       NaN    525   80      82
# 4   254                 Sceptile  Grass       NaN    530   70      85
# 5   254    SceptileMega Sceptile  Grass    Dragon    630   70     110
# 6   389                 Torterra  Grass    Ground    525   95     109
# 7   407                 Roserade  Grass    Poison    515   60      70
# 8   460  AbomasnowMega Abomasnow  Grass       Ice    594   90     132
# 9   465                Tangrowth  Grass       NaN    535  100     100
# 10  470                  Leafeon  Grass       NaN    525   65     110
# 11  492        ShayminLand Forme  Grass       NaN    600  100     100
# ...

# %% [markdown]
# ## Advance Filter

# %%
import re 
df.loc[df['Type 1'].str.contains('water|bug',flags=re.I,regex=True)] # like search engine
df.loc[df['Name'].str.contains('^pi[a-z]*',flags=re.I,regex=True)] # to take only pi and remaining a to z all, ^ - indicates starting
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying    251   40      45
# 21    17            Pidgeotto    Normal    Flying    349   63      60
# 22    18              Pidgeot    Normal    Flying    479   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 30    25              Pikachu  Electric       NaN    320   35      55
# 136  127               Pinsir       Bug       NaN    500   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying    600   65     155
# 186  172                Pichu  Electric       NaN    205   20      40
# 219  204               Pineco       Bug       NaN    290   50      65
# 239  221            Piloswine       Ice    Ground    450  100     100
# 438  393               Piplup     Water       NaN    314   53      51
# 558  499              Pignite      Fire  Fighting    418   90      93
# ...

# %% [markdown]
# ## Conditional Changes

# %%
df.loc[df['Type 1'] == 'Fire','Type 1'] = "monkey" # replace the value  - for single
df.loc[df['Total'] < 400, ['Attack', 'Defense']] = ["Waste A", "Waste def"] # for multiple
df.loc[df['Type 1'] == 'monkey']
# Out:
#        #                       Name  Type 1    Type 2  Total   HP   Attack  \
# 4      4                 Charmander  monkey       NaN    309   39  Waste A
# 5      5                 Charmeleon  monkey       NaN    405   58       64
# 6      6                  Charizard  monkey    Flying    534   78       84
# 7      6  CharizardMega Charizard X  monkey    Dragon    634   78      130
# 8      6  CharizardMega Charizard Y  monkey    Flying    634   78      104
# 42    37                     Vulpix  monkey       NaN    299   38  Waste A
# 43    38                  Ninetales  monkey       NaN    505   73       76
# 63    58                  Growlithe  monkey       NaN    350   55  Waste A
# 64    59                   Arcanine  monkey       NaN    555   90      110
# 83    77                     Ponyta  monkey       NaN    410   50       85
# 84    78                   Rapidash  monkey       NaN    500   65      100
# ...

# %% [markdown]
# ## Aggregate Statistics (Group By)

# %%
df = pd.read_csv('p_learn/pokemon_data.csv')
df.head()
df.groupby(['Name']).mean(numeric_only=True).sort_values('Speed',ascending=True) # to verify the which one power for specific power
df.groupby(['Type 1','Type 2']).count()['Attack'] # For specific column
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: Attack, Length: 136, dtype: int64

# %%
df.loc[df['Legendary'] == True,'Legendary'] = "Periya Kai"
df.loc[df['Legendary'] == False,'Legendary'] = "Kutty kai"
df['Legendary'].value_counts()
# Out:
# Legendary
# Kutty kai     735
# Periya Kai     65
# Name: count, dtype: int64

# %% [markdown]
# ## Working with Large Datasets

# %%
new_df = pd.DataFrame(columns= df.columns)

for df in pd.read_csv('p_learn/pokemon_data.csv',chunksize=5):
    result = df.groupby('Type 1').mean(numeric_only =True)
    new_df = pd.concat([new_df, result])
    
new_df
# Out:
#               # Name Type 1 Type 2      HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Fire       4.00  NaN    NaN    NaN   39.00   52.00    43.00    60.00    50.00
# Grass      2.25  NaN    NaN    NaN   66.25   73.25    79.50    91.75    91.25
# Fire       5.75  NaN    NaN    NaN   73.00   95.50    81.25   119.50    87.50
# Water      7.00  NaN    NaN    NaN   44.00   48.00    65.00    50.00    64.00
# Bug       10.50  NaN    NaN    NaN   47.50   25.00    45.00    22.50    22.50
# ...         ...  ...    ...    ...     ...     ...      ...      ...      ...
# Fairy    716.00  NaN    NaN    NaN  126.00  131.00    95.00   131.00    98.00
# Flying   714.50  NaN    NaN    NaN   62.50   50.00    57.50    71.00    60.00
# Fire     721.00  NaN    NaN    NaN   80.00  110.00   120.00   130.00    90.00
# Psychic  720.00  NaN    NaN    NaN   80.00  135.00    60.00   160.00   130.00
# Rock     719.00  NaN    NaN    NaN   50.00  130.00   130.00   130.00   130.00
#
# ...
